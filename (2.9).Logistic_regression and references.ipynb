# %% [markdown]
# # Logistic regression

# %%
# using logistic regression
lr = LogisticRegression(multi_class='ovr')
lr.fit(x_train,y_train)
y_train_pred = lr.predict(x_train)
y_pred = lr.predict(x_test)
acc_train = accuracy_score(y_train,y_train_pred)
acc_test = accuracy_score(y_test,y_pred)
print(f'Accuracy on train data - {acc_train}')
print(f'Accuracy on test data - {acc_test}')
# Out:
# Accuracy on train data - 0.7588747488278633
# Accuracy on test data - 0.7469879518072289

# %%
# Confusion metrix of test data
cm = confusion_matrix(y_test,y_pred)
labels = ['Excellent','Good','Poor','Very Poor','Non-drinkable']
plt.figure(figsize=(12, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',xticklabels = labels, yticklabels = labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ## References
#
# 1. [Water Quality Assessment in Terms of Water Quality Index](http://pubs.sciepub.com/ajwr/1/3/3/index.html)
# 2. [Modelling and Prediction of Water Quality by Using Artificial Intelligence](https://www.mdpi.com/2071-1050/13/8/4259/pdf)
