# %% [markdown]
# ## Logistic Regression

# %%
# using logistic regression
lr = LogisticRegression(multi_class='ovr')
lr.fit(x_train,y_train)
y_train_pred_lr = lr.predict(x_train)
y_pred_lr = lr.predict(x_test)
acc_train_lr = accuracy_score(y_train,y_train_pred_lr)
acc_test_lr = accuracy_score(y_test,y_pred_lr)
print(f'Accuracy on train data : {acc_train_lr}')
print(f'Accuracy on test data : {acc_test_lr}')
print('Classification Report for Logistic Regression')
print(classification_report(y_test,y_pred_lr))
# Out:
# Accuracy on train data : 0.7588747488278633
# Accuracy on test data : 0.7469879518072289
# Classification Report for Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.84      0.80      0.82       117
#            2       0.64      0.92      0.75       195
#            3       0.00      0.00      0.00        81
#            4       0.95      0.96      0.96       103
#
#     accuracy                           0.75       498
#    macro avg       0.49      0.54      0.51       498
# weighted avg       0.64      0.75      0.69       498

# %%
# Confusion metrix of test data
cm = confusion_matrix(y_test,y_pred_lr)
labels = ['Excellent','Good','Poor','Very Poor','Non-drinkable']
plt.figure(figsize=(12, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',xticklabels = labels, yticklabels = labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Logistic Regression')
plt.show()

# %% [markdown]
# ## KNN

# %%
#using knn classifier
knn=KNeighborsClassifier(n_neighbors=10)
knn.fit(x_train,y_train)
y_train_pred_knn=knn.predict(x_train)
y_pred_knn=knn.predict(x_test)
acc_train_knn=accuracy_score(y_train,y_train_pred_knn)
acc_test_knn=accuracy_score(y_test,y_pred_knn)
print(f'accuracy on train data : {acc_train_knn}')
print(f'accuracy on test data : {acc_test_knn}')
print('Classification Report for KNN')
print(classification_report(y_test,y_pred_knn))
# Out:
# accuracy on train data : 0.6222371064969859
# accuracy on test data : 0.5682730923694779
# Classification Report for KNN
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         2
#            1       0.56      0.63      0.60       117
#            2       0.58      0.66      0.62       195
#            3       0.46      0.35      0.39        81
#            4       0.62      0.51      0.56       103
#
#     accuracy                           0.57       498
#    macro avg       0.45      0.43      0.43       498
# weighted avg       0.56      0.57      0.56       498

# %%
# Confusion metrix of test data
cm = confusion_matrix(y_test,y_pred_knn)
labels = ['Excellent','Good','Poor','Very Poor','Non-drinkable']
plt.figure(figsize=(12, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',xticklabels = labels, yticklabels = labels)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for KNN')
plt.show()
