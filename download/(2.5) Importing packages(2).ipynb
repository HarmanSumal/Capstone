# %% [markdown]
# ## Importing Packages

# %%
# !pip install seaborn
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import os

from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split,cross_val_score, RandomizedSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
# Out:
# Requirement already satisfied: seaborn in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (0.12.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (from seaborn) (1.21.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (from seaborn) (3.6.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (from seaborn) (1.4.3)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.37.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.5)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (1.7.6)
# Requirement already satisfied: scipy in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (from xgboost) (1.7.3)
# Requirement already satisfied: numpy in c:\users\manpr\anaconda3\envs\dab300a\lib\site-packages (from xgboost) (1.21.5)

# %%
from xgboost import XGBClassifier

# %% [markdown]
# ## Data Pre-processing

# %%
fpath = os.path.join(os.getcwd(),'water_dataX.csv')

# %%
data = pd.read_csv(fpath,encoding="unicode_escape")
data.head()
# Out:
#   ï»¿STATION CODE                                          LOCATIONS  \
# 0            1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1            1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2            1475                                ZUARI AT PANCHAWADI
# 3            3181                        RIVER ZUARI AT BORIM BRIDGE
# 4            3182                       RIVER ZUARI AT MARCAIM JETTY
#
#          STATE  Temp D.O. (mg/l)   PH CONDUCTIVITY (Âµmhos/cm) B.O.D. (mg/l)  \
# 0  DAMAN & DIU  30.6         6.7  7.5                      203           NAN
# 1          GOA  29.8         5.7  7.2                      189             2
# 2          GOA  29.5         6.3  6.9                      179           1.7
# 3          GOA  29.7         5.8  6.9                       64           3.8
# 4          GOA  29.5         5.8  7.3                       83           1.9
#
#   NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# 0                              0.1                         11
# 1                              0.2                       4953
# 2                              0.1                       3243
# 3                              0.5                       5382
# 4                              0.4                       3428
#
#   TOTAL COLIFORM (MPN/100ml)Mean  year
# 0                             27  2014
# 1                           8391  2014
# 2                           5330  2014
# 3                           8443  2014
# 4                           5500  2014

# %%
# to see the data types and check for null values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1991 entries, 0 to 1990
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   ï»¿STATION CODE                   1991 non-null   object
#  1   LOCATIONS                         1991 non-null   object
#  2   STATE                             1991 non-null   object
#  3   Temp                              1991 non-null   object
#  4   D.O. (mg/l)                       1991 non-null   object
#  5   PH                                1991 non-null   object
#  6   CONDUCTIVITY (Âµmhos/cm)          1991 non-null   object
#  7   B.O.D. (mg/l)                     1991 non-null   object
#  8   NITRATENAN N+ NITRITENANN (mg/l)  1991 non-null   object
#  9   FECAL COLIFORM (MPN/100ml)        1991 non-null   object
#  10  TOTAL COLIFORM (MPN/100ml)Mean    1991 non-null   object
#  11  year                              1991 non-null   int64
# dtypes: int64(1), object(11)
# memory usage: 186.8+ KB

# %% [markdown]
# We did not get any null values because we have all the numerical features as a text

# %%
# convert all the columns to numeric except the text column
num_columns = []
for col in data.columns:
    if col not in ['STATION CODE','LOCATIONS','STATE','year']:
        data[col] = pd.to_numeric(data[col],errors='coerce')
        num_columns.append(col)

# %% [markdown]
# Numerical columns will be important to identify the water quality index as it should independent of the place and year and should only be depending upon the test results.

# %% [markdown]
# Let's check the null values

# %%
data.isna().sum()
# Out:
# ï»¿STATION CODE                     122
# LOCATIONS                             0
# STATE                                 0
# Temp                                 92
# D.O. (mg/l)                          31
# PH                                    8
# CONDUCTIVITY (Âµmhos/cm)             25
# B.O.D. (mg/l)                        43
# NITRATENAN N+ NITRITENANN (mg/l)    225
# FECAL COLIFORM (MPN/100ml)          316
# TOTAL COLIFORM (MPN/100ml)Mean      132
# year                                  0
# dtype: int64

# %%
# changing the column name
data = data[num_columns[-8:]]
num_columns = ['temp','Disolved oxygen','ph','conductivity','Biochemical oxygen Demand','nitratenan','fecal_coliform','total_coliform']
data.columns = num_columns
data.head()
# Out:
#    temp  Disolved oxygen   ph  conductivity  Biochemical oxygen Demand  \
# 0  30.6              6.7  7.5         203.0                        NaN
# 1  29.8              5.7  7.2         189.0                        2.0
# 2  29.5              6.3  6.9         179.0                        1.7
# 3  29.7              5.8  6.9          64.0                        3.8
# 4  29.5              5.8  7.3          83.0                        1.9
#
#    nitratenan  fecal_coliform  total_coliform
# 0         0.1            11.0            27.0
# 1         0.2          4953.0          8391.0
# 2         0.1          3243.0          5330.0
# 3         0.5          5382.0          8443.0
# 4         0.4          3428.0          5500.0

# %% [markdown]
# We will impute the null values in the data with the median values so that the distribution does not change much

# %%
# Null value imputation
imputer = SimpleImputer(strategy='median')
data = pd.DataFrame(imputer.fit_transform(data),columns=data.columns)

# %%
# to get the idea how the features are correlated
cor = data.corr()
cor.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T_95852_row0_col0, #T_95852_row1_col1, #T_95852_row2_col2, #T_95852_row3_col3, #T_95852_row4_col4, #T_95852_row5_col5, #T_95852_row6_col6, #T_95852_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_95852_row0_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_95852_row0_col2, #T_95852_row5_col1 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_95852_row0_col3 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_95852_row0_col4 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_95852_row0_col5, #T_95852_row1_col3, #T_95852_row1_col4, #T_95852_row1_col6, #T_95852_row1_col7, #T_95852_row3_col2, #T_95852_row4_col1, #T_95852_row5_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_95852_row0_col6 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_95852_row0_col7, #T_95852_row3_col6, #T_95852_row4_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_95852_row1_col0 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_95852_row1_col2 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_95852_row1_col5, #T_95852_row5_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_95852_row2_col0 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_95852_row2_col1, #T_95852_row3_col5, #T_95852_row4_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_95852_row2_col3, #T_95852_row3_col7, #T_95852_row5_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_95852_row2_col4 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_95852_row2_col5 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_95852_row2_col6, #T_95852_row2_col7, #T_95852_row5_col7 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_95852_row3_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_95852_row3_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_95852_row3_col4, #T_95852_row4_col5 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_95852_row4_col2 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_95852_row4_col6 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_95852_row4_col7 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_95852_row5_col3 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_95852_row5_col4 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_95852_row6_col0 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_95852_row6_col1, #T_95852_row7_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_95852_row6_col2, #T_95852_row7_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_95852_row6_col3, #T_95852_row7_col3 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_95852_row6_col4 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_95852_row6_col5, #T_95852_row7_col5 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_95852_row6_col7, #T_95852_row7_col6 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_95852_row7_col0 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_95852_row7_col4 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# </style>
# <table id="T_95852" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95852_level0_col0" class="col_heading level0 col0" >temp</th>
#       <th id="T_95852_level0_col1" class="col_heading level0 col1" >Disolved oxygen</th>
#       <th id="T_95852_level0_col2" class="col_heading level0 col2" >ph</th>
#       <th id="T_95852_level0_col3" class="col_heading level0 col3" >conductivity</th>
#       <th id="T_95852_level0_col4" class="col_heading level0 col4" >Biochemical oxygen Demand</th>
#       <th id="T_95852_level0_col5" class="col_heading level0 col5" >nitratenan</th>
#       <th id="T_95852_level0_col6" class="col_heading level0 col6" >fecal_coliform</th>
#       <th id="T_95852_level0_col7" class="col_heading level0 col7" >total_coliform</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95852_level0_row0" class="row_heading level0 row0" >temp</th>
#       <td id="T_95852_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_95852_row0_col1" class="data row0 col1" >0.03</td>
#       <td id="T_95852_row0_col2" class="data row0 col2" >0.02</td>
#       <td id="T_95852_row0_col3" class="data row0 col3" >0.14</td>
#       <td id="T_95852_row0_col4" class="data row0 col4" >-0.05</td>
#       <td id="T_95852_row0_col5" class="data row0 col5" >-0.21</td>
#       <td id="T_95852_row0_col6" class="data row0 col6" >0.01</td>
#       <td id="T_95852_row0_col7" class="data row0 col7" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_95852_level0_row1" class="row_heading level0 row1" >Disolved oxygen</th>
#       <td id="T_95852_row1_col0" class="data row1 col0" >0.03</td>
#       <td id="T_95852_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_95852_row1_col2" class="data row1 col2" >0.03</td>
#       <td id="T_95852_row1_col3" class="data row1 col3" >-0.16</td>
#       <td id="T_95852_row1_col4" class="data row1 col4" >-0.24</td>
#       <td id="T_95852_row1_col5" class="data row1 col5" >-0.20</td>
#       <td id="T_95852_row1_col6" class="data row1 col6" >-0.14</td>
#       <td id="T_95852_row1_col7" class="data row1 col7" >-0.14</td>
#     </tr>
#     <tr>
#       <th id="T_95852_level0_row2" class="row_heading level0 row2" >ph</th>
#       <td id="T_95852_row2_col0" class="data row2 col0" >0.02</td>
#       <td id="T_95852_row2_col1" class="data row2 col1" >0.03</td>
#       <td id="T_95852_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_95852_row2_col3" class="data row2 col3" >-0.02</td>
#       <td id="T_95852_row2_col4" class="data row2 col4" >0.04</td>
#       <td id="T_95852_row2_col5" class="data row2 col5" >-0.01</td>
#       <td id="T_95852_row2_col6" class="data row2 col6" >-0.00</td>
#       <td id="T_95852_row2_col7" class="data row2 col7" >-0.00</td>
#     </tr>
#     <tr>
#       <th id="T_95852_level0_row3" class="row_heading level0 row3" >conductivity</th>
#       <td id="T_95852_row3_col0" class="data row3 col0" >0.14</td>
#       <td id="T_95852_row3_col1" class="data row3 col1" >-0.16</td>
#       <td id="T_95852_row3_col2" class="data row3 col2" >-0.02</td>
#       <td id="T_95852_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_95852_row3_col4" class="data row3 col4" >0.10</td>
#       <td id="T_95852_row3_col5" class="data row3 col5" >0.07</td>
#       <td id="T_95852_row3_col6" class="data row3 col6" >0.00</td>
#       <td id="T_95852_row3_col7" class="data row3 col7" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_95852_level0_row4" class="row_heading level0 row4" >Biochemical oxygen Demand</th>
#       <td id="T_95852_row4_col0" class="data row4 col0" >-0.05</td>
#       <td id="T_95852_row4_col1" class="data row4 col1" >-0.24</td>
#       <td id="T_95852_row4_col2" class="data row4 col2" >0.04</td>
#       <td id="T_95852_row4_col3" class="data row4 col3" >0.10</td>
#       <td id="T_95852_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_95852_row4_col5" class="data row4 col5" >0.13</td>
#       <td id="T_95852_row4_col6" class="data row4 col6" >0.18</td>
#       <td id="T_95852_row4_col7" class="data row4 col7" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_95852_level0_row5" class="row_heading level0 row5" >nitratenan</th>
#       <td id="T_95852_row5_col0" class="data row5 col0" >-0.21</td>
#       <td id="T_95852_row5_col1" class="data row5 col1" >-0.20</td>
#       <td id="T_95852_row5_col2" class="data row5 col2" >-0.01</td>
#       <td id="T_95852_row5_col3" class="data row5 col3" >0.07</td>
#       <td id="T_95852_row5_col4" class="data row5 col4" >0.13</td>
#       <td id="T_95852_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_95852_row5_col6" class="data row5 col6" >-0.00</td>
#       <td id="T_95852_row5_col7" class="data row5 col7" >-0.00</td>
#     </tr>
#     <tr>
#       <th id="T_95852_level0_row6" class="row_heading level0 row6" >fecal_coliform</th>
#       <td id="T_95852_row6_col0" class="data row6 col0" >0.01</td>
#       <td id="T_95852_row6_col1" class="data row6 col1" >-0.14</td>
#       <td id="T_95852_row6_col2" class="data row6 col2" >-0.00</td>

# %% [markdown]
# From above correlation plot, it is clear that the fecal_coloform and total coliform are highly correlated with each other. So, we are going to remove fecal_coliform as it will be included in total_coliform.

# %%
data = data.drop(['fecal_coliform'],axis =1 )

# %% [markdown]
# Based on the features we need to calculate the Water Quality Index (WQI) to know if the water is potable or not.

# %%
# define some standard parameters
Si = {'Disolved oxygen' : 10,
      'ph' : 8.5,
      'conductivity' : 1000,
      'Biochemical oxygen Demand' : 5,
      'nitratenan' : 45,
      'total_coliform' : 1000
      }
# Ideal values from each parameter
Videal = {'Disolved oxygen' : 14.6,
          'ph' : 7,
          'conductivity' : 0,
          'Biochemical oxygen Demand' : 0,
          'nitratenan' : 0,
          'total_coliform' : 0
          }

# Uniw weights calculations
K = 1/sum([1/i for i in Si.values()])
Wi = {}
for key in Si:
    Wi[key] = K/Si[key]

# %%
# to calculate the target variable
def calculate_wqi(data,Si,Wi,Videal):
    df = data.copy()

    for col in Si.keys():
        df[col] = 100 * ((df[col]- Videal[col])/(Si[col] - Videal[col])) * Wi[col]

    return df[Si.keys()].sum(axis = 1)/sum(Wi.values())

# %%
data['target'] = calculate_wqi(data,Si,Wi,Videal)

 # classifying the target variable based on reference[1]
target_conditions = [data['target']<=25, # Excellent
                     (data['target']<=50) & (data['target']>=25), # Good
                     (data['target']<=75) & (data['target']>=50), # Poor
                     (data['target']<=100) & (data['target']>=75), # Very poor
                     data['target']>100 # non-drinkable
                     ]
values = [0,1,2,3,4]
data['target'] = np.select(target_conditions,values)

# %%
x_train,x_test,y_train,y_test = train_test_split(data.drop('target',axis =1),data['target'],random_state = 42,stratify = data['target'])

# %% [markdown]
# References:-
#
#
# http://article.journalofwaterresources.com/pdf/ajwr-1-3-3.pdf
#
#
# https://www.mdpi.com/2071-1050/13/8/4259/pdf
