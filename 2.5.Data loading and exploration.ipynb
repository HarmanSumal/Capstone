# %% [markdown]
# ## Loading the required packages

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import os

from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score,confusion_matrix
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

# %%
fpath = os.path.join(os.getcwd(),'water_dataX.csv')

# %% [markdown]
# ## Data loading and exploration

# %%
data = pd.read_csv(fpath,encoding="unicode_escape")  # read the data
data.head()
# Out:
#   STATION CODE                                          LOCATIONS  \
# 0         1393               DAMANGANGA AT D/S OF MADHUBAN, DAMAN
# 1         1399  ZUARI AT D/S OF PT. WHERE KUMBARJRIA CANAL JOI...
# 2         1475                                ZUARI AT PANCHAWADI
# 3         3181                        RIVER ZUARI AT BORIM BRIDGE
# 4         3182                       RIVER ZUARI AT MARCAIM JETTY
#
#          STATE  Temp D.O. (mg/l)   PH CONDUCTIVITY (µmhos/cm) B.O.D. (mg/l)  \
# 0  DAMAN & DIU  30.6         6.7  7.5                     203           NAN
# 1          GOA  29.8         5.7  7.2                     189             2
# 2          GOA  29.5         6.3  6.9                     179           1.7
# 3          GOA  29.7         5.8  6.9                      64           3.8
# 4          GOA  29.5         5.8  7.3                      83           1.9
#
#   NITRATENAN N+ NITRITENANN (mg/l) FECAL COLIFORM (MPN/100ml)  \
# 0                              0.1                         11
# 1                              0.2                       4953
# 2                              0.1                       3243
# 3                              0.5                       5382
# 4                              0.4                       3428
#
#   TOTAL COLIFORM (MPN/100ml)Mean  year
# 0                             27  2014
# 1                           8391  2014
# 2                           5330  2014
# 3                           8443  2014
# 4                           5500  2014

# %%
# to see the data types and check for null values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1991 entries, 0 to 1990
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   STATION CODE                      1991 non-null   object
#  1   LOCATIONS                         1991 non-null   object
#  2   STATE                             1991 non-null   object
#  3   Temp                              1991 non-null   object
#  4   D.O. (mg/l)                       1991 non-null   object
#  5   PH                                1991 non-null   object
#  6   CONDUCTIVITY (µmhos/cm)           1991 non-null   object
#  7   B.O.D. (mg/l)                     1991 non-null   object
#  8   NITRATENAN N+ NITRITENANN (mg/l)  1991 non-null   object
#  9   FECAL COLIFORM (MPN/100ml)        1991 non-null   object
#  10  TOTAL COLIFORM (MPN/100ml)Mean    1991 non-null   object
#  11  year                              1991 non-null   int64
# dtypes: int64(1), object(11)
# memory usage: 186.8+ KB

# %% [markdown]
# We did not get any null values because we have all the numerical features as a text

# %%
# convert all the columns to numeric except the text column
num_columns = []
for col in data.columns:
    if col not in ['STATION CODE','LOCATIONS','STATE','year']:
        data[col] = pd.to_numeric(data[col],errors='coerce')
        num_columns.append(col)

# %% [markdown]
# Numerical columns will be important to identify the water quality index as it should independent of the place and year and should only be depending upon the test results.
#
# Let's check the null values

# %%
data.isna().sum()  # calculate the missing values
# Out:
# STATION CODE                          0
# LOCATIONS                             0
# STATE                                 0
# Temp                                 92
# D.O. (mg/l)                          31
# PH                                    8
# CONDUCTIVITY (µmhos/cm)              25
# B.O.D. (mg/l)                        43
# NITRATENAN N+ NITRITENANN (mg/l)    225
# FECAL COLIFORM (MPN/100ml)          316
# TOTAL COLIFORM (MPN/100ml)Mean      132
# year                                  0
# dtype: int64

# %%
# changing the column name
data = data[num_columns]
num_columns = ['temp','do','ph','conductivity','bod','nitratenan','fecal_coliform','total_coliform']
data.columns = num_columns 
data.head()
# Out:
#    temp   do   ph  conductivity  bod  nitratenan  fecal_coliform  \
# 0  30.6  6.7  7.5         203.0  NaN         0.1            11.0
# 1  29.8  5.7  7.2         189.0  2.0         0.2          4953.0
# 2  29.5  6.3  6.9         179.0  1.7         0.1          3243.0
# 3  29.7  5.8  6.9          64.0  3.8         0.5          5382.0
# 4  29.5  5.8  7.3          83.0  1.9         0.4          3428.0
#
#    total_coliform
# 0            27.0
# 1          8391.0
# 2          5330.0
# 3          8443.0
# 4          5500.0

# %% [markdown]
# We will impute the null values in the data with the median values so that the distribution does not change much

# %%
# Null value imputation
imputer = SimpleImputer(strategy='median')
data = pd.DataFrame(imputer.fit_transform(data),columns=data.columns)

# %%
# to get the idea how the features are correlated
cor = data.corr()
cor.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_b635a_row0_col0,#T_b635a_row1_col1,#T_b635a_row2_col2,#T_b635a_row3_col3,#T_b635a_row4_col4,#T_b635a_row5_col5,#T_b635a_row6_col6,#T_b635a_row7_col7{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_b635a_row0_col1{
#             background-color:  #81a4fb;
#             color:  #000000;
#         }#T_b635a_row0_col2,#T_b635a_row5_col1{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_b635a_row0_col3{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_b635a_row0_col4{
#             background-color:  #6c8ff1;
#             color:  #000000;
#         }#T_b635a_row0_col5,#T_b635a_row1_col3,#T_b635a_row1_col4,#T_b635a_row1_col6,#T_b635a_row1_col7,#T_b635a_row3_col2,#T_b635a_row4_col1,#T_b635a_row5_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_b635a_row0_col6{
#             background-color:  #6485ec;
#             color:  #000000;
#         }#T_b635a_row0_col7,#T_b635a_row3_col6,#T_b635a_row4_col0{
#             background-color:  #6384eb;
#             color:  #000000;
#         }#T_b635a_row1_col0{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_b635a_row1_col2{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_b635a_row1_col5,#T_b635a_row5_col2{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_b635a_row2_col0{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_b635a_row2_col1,#T_b635a_row3_col5,#T_b635a_row4_col3{
#             background-color:  #84a7fc;
#             color:  #000000;
#         }#T_b635a_row2_col3,#T_b635a_row3_col7,#T_b635a_row5_col6{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_b635a_row2_col4{
#             background-color:  #85a8fc;
#             color:  #000000;
#         }#T_b635a_row2_col5{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_b635a_row2_col6,#T_b635a_row2_col7,#T_b635a_row5_col7{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_b635a_row3_col0{
#             background-color:  #9bbcff;
#             color:  #000000;
#         }#T_b635a_row3_col1{
#             background-color:  #4e68d8;
#             color:  #000000;
#         }#T_b635a_row3_col4,#T_b635a_row4_col5{
#             background-color:  #96b7ff;
#             color:  #000000;
#         }#T_b635a_row4_col2{
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }#T_b635a_row4_col6{
#             background-color:  #98b9ff;
#             color:  #000000;
#         }#T_b635a_row4_col7{
#             background-color:  #93b5fe;
#             color:  #000000;
#         }#T_b635a_row5_col3{
#             background-color:  #7a9df8;
#             color:  #000000;
#         }#T_b635a_row5_col4{
#             background-color:  #9dbdff;
#             color:  #000000;
#         }#T_b635a_row6_col0{
#             background-color:  #7597f6;
#             color:  #000000;
#         }#T_b635a_row6_col1,#T_b635a_row7_col1{
#             background-color:  #536edd;
#             color:  #000000;
#         }#T_b635a_row6_col2,#T_b635a_row7_col2{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_b635a_row6_col3,#T_b635a_row7_col3{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_b635a_row6_col4{
#             background-color:  #abc8fd;
#             color:  #000000;
#         }#T_b635a_row6_col5,#T_b635a_row7_col5{
#             background-color:  #7093f3;
#             color:  #000000;
#         }#T_b635a_row6_col7,#T_b635a_row7_col6{
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }#T_b635a_row7_col0{
#             background-color:  #7396f5;
#             color:  #000000;
#         }#T_b635a_row7_col4{
#             background-color:  #a7c5fe;
#             color:  #000000;
#         }</style><table id="T_b635a_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >temp</th>        <th class="col_heading level0 col1" >do</th>        <th class="col_heading level0 col2" >ph</th>        <th class="col_heading level0 col3" >conductivity</th>        <th class="col_heading level0 col4" >bod</th>        <th class="col_heading level0 col5" >nitratenan</th>        <th class="col_heading level0 col6" >fecal_coliform</th>        <th class="col_heading level0 col7" >total_coliform</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b635a_level0_row0" class="row_heading level0 row0" >temp</th>
#                         <td id="T_b635a_row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_b635a_row0_col1" class="data row0 col1" >0.03</td>
#                         <td id="T_b635a_row0_col2" class="data row0 col2" >0.02</td>
#                         <td id="T_b635a_row0_col3" class="data row0 col3" >0.14</td>
#                         <td id="T_b635a_row0_col4" class="data row0 col4" >-0.05</td>
#                         <td id="T_b635a_row0_col5" class="data row0 col5" >-0.21</td>
#                         <td id="T_b635a_row0_col6" class="data row0 col6" >0.01</td>
#                         <td id="T_b635a_row0_col7" class="data row0 col7" >0.01</td>
#             </tr>
#             <tr>
#                         <th id="T_b635a_level0_row1" class="row_heading level0 row1" >do</th>
#                         <td id="T_b635a_row1_col0" class="data row1 col0" >0.03</td>
#                         <td id="T_b635a_row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_b635a_row1_col2" class="data row1 col2" >0.03</td>
#                         <td id="T_b635a_row1_col3" class="data row1 col3" >-0.16</td>
#                         <td id="T_b635a_row1_col4" class="data row1 col4" >-0.24</td>
#                         <td id="T_b635a_row1_col5" class="data row1 col5" >-0.20</td>
#                         <td id="T_b635a_row1_col6" class="data row1 col6" >-0.14</td>
#                         <td id="T_b635a_row1_col7" class="data row1 col7" >-0.14</td>
#             </tr>
#             <tr>
#                         <th id="T_b635a_level0_row2" class="row_heading level0 row2" >ph</th>
#                         <td id="T_b635a_row2_col0" class="data row2 col0" >0.02</td>
#                         <td id="T_b635a_row2_col1" class="data row2 col1" >0.03</td>
#                         <td id="T_b635a_row2_col2" class="data row2 col2" >1.00</td>
#                         <td id="T_b635a_row2_col3" class="data row2 col3" >-0.02</td>
#                         <td id="T_b635a_row2_col4" class="data row2 col4" >0.04</td>
#                         <td id="T_b635a_row2_col5" class="data row2 col5" >-0.01</td>
#                         <td id="T_b635a_row2_col6" class="data row2 col6" >-0.00</td>
#                         <td id="T_b635a_row2_col7" class="data row2 col7" >-0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_b635a_level0_row3" class="row_heading level0 row3" >conductivity</th>
#                         <td id="T_b635a_row3_col0" class="data row3 col0" >0.14</td>
#                         <td id="T_b635a_row3_col1" class="data row3 col1" >-0.16</td>
#                         <td id="T_b635a_row3_col2" class="data row3 col2" >-0.02</td>
#                         <td id="T_b635a_row3_col3" class="data row3 col3" >1.00</td>
#                         <td id="T_b635a_row3_col4" class="data row3 col4" >0.10</td>
#                         <td id="T_b635a_row3_col5" class="data row3 col5" >0.07</td>
#                         <td id="T_b635a_row3_col6" class="data row3 col6" >0.00</td>
#                         <td id="T_b635a_row3_col7" class="data row3 col7" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_b635a_level0_row4" class="row_heading level0 row4" >bod</th>
#                         <td id="T_b635a_row4_col0" class="data row4 col0" >-0.05</td>
#                         <td id="T_b635a

# %% [markdown]
# From above correlation plot, it is clear that the fecal_coloform and total coliform are highly correlated with each other. So, we are going to remove fecal_coliform as it will be included in total_coliform.

# %%
data = data.drop(['fecal_coliform'],axis =1 )   # drop used to remove the column named fecal_coliform

# %% [markdown]
# Based on the features we need to calculate the Water Quality Index (WQI) to know if the water is potable or not. For that we are going to refer the Reference[1] and Reference[2]

# %%
# define some standard parameters
Si = {'do' : 10,
      'ph' : 8.5,
      'conductivity' : 1000,
      'bod' : 5,
      'nitratenan' : 45,
      'total_coliform' : 1000
      }
# Ideal values from each parameter
Videal = {'do' : 14.6,
          'ph' : 7,
          'conductivity' : 0,
          'bod' : 0,
          'nitratenan' : 0,
          'total_coliform' : 0
          }

# Uniw weights calculations
K = 1/sum([1/i for i in Si.values()])
Wi = {}
for key in Si:
    Wi[key] = K/Si[key]

# %%
# to calculate the target variable
def calculate_wqi(data,Si,Wi,Videal):
    df = data.copy()
    
    for col in Si.keys():
        df[col] = 100 * ((df[col]- Videal[col])/(Si[col] - Videal[col])) * Wi[col]
    
    return df[Si.keys()].sum(axis = 1)/sum(Wi.values())

# %%
data['target'] = calculate_wqi(data,Si,Wi,Videal)

 # classifying the target variable based on reference[1]
target_conditions = [data['target']<=25, # Excellent
                     (data['target']<=50) & (data['target']>=25), # Good
                     (data['target']<=75) & (data['target']>=50), # Poor
                     (data['target']<=100) & (data['target']>=75), # Very poor
                     data['target']>100 # non-drinkable
                     ]
values = [0,1,2,3,4]
data['target'] = np.select(target_conditions,values)
